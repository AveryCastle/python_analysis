# %%
# %matplotlib nbagg

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
sr = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
sr
# Out:
# 0    -0.825668
# 10   -0.820043
# 20   -1.558650
# 30   -2.943595
# 40   -3.626483
# 50   -3.210747
# 60   -3.440065
# 70   -3.146772
# 80   -3.396092
# 90   -2.564526
# dtype: float64

# %%
sr.plot()
plt.savefig('figure1.svg')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -1.594757  0.104338  0.745009 -2.051274
# 10 -1.469617 -1.794425 -1.212625 -0.788704
# 20 -0.665083 -3.939443 -0.937785 -0.342523
# 30 -0.073895 -5.576540  0.343090 -1.102306
# 40  0.366547 -5.146638 -0.257139 -1.457753
# 50  0.548565 -4.573811 -1.500084 -2.604471
# 60 -0.299007 -4.292878 -2.889571 -1.629491
# 70 -1.057702 -5.705592 -1.979468 -1.747635
# 80 -2.444969 -5.537792 -4.369621 -1.036364
# 90 -1.802732 -5.337313 -2.559779 -0.968315

# %%
df.plot()
plt.savefig('figure1.svg')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['A'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))
sr2
# Out:
# a    0.165321
# b    0.580585
# c    0.464536
# d    0.104937
# e    0.997791
# f    0.838292
# g    0.297849
# h    0.660289
# i    0.971286
# j    0.976911
# k    0.789414
# l    0.885862
# m    0.659459
# n    0.821549
# o    0.941546
# dtype: float64

# %%
sr2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
# !pip install pandas==0.23.0

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Number"))
df2
# Out:
# Number         A         B         C         D
# one     0.452739  0.424075  0.978688  0.977469
# two     0.523814  0.136146  0.581212  0.424848
# three   0.293836  0.532353  0.458077  0.630987
# four    0.105600  0.368792  0.140498  0.340964
# five    0.315427  0.093749  0.734530  0.292319
# six     0.485573  0.862456  0.946042  0.108696

# %%
df2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
