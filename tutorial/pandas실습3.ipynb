# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(5,4))

# %%
df.columns = ['A', 'B', 'C','D']

# %%
df
# Out:
#           A         B         C         D
# 0 -1.257992  0.260599  0.379224  0.414422
# 1  0.520824 -0.950151 -1.856481  0.438979
# 2  0.511370 -1.078917 -0.854772  0.517124
# 3 -0.221041 -0.343906  0.580658 -0.451254
# 4 -0.164922 -0.258214  2.397624  0.943152

# %%
df.index = pd.date_range('20180214', periods=5)

# %%
df
# Out:
#                    A         B         C         D
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
#df['E' ] = [10, 9,8]

# %%
df['E' ] = [10, np.nan, 9,8, np.nan]

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   NaN
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   NaN

# %%
#df.drop?

# %%
#df.dropna?

# %%
df.dropna(how='any')
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0

# %%
df.dropna(how='all')
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   NaN
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   NaN

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   NaN
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   NaN

# %%
df.isnull()
# Out:
#                 A      B      C      D      E
# 2018-02-14  False  False  False  False  False
# 2018-02-15  False  False  False  False   True
# 2018-02-16  False  False  False  False  False
# 2018-02-17  False  False  False  False  False
# 2018-02-18  False  False  False  False   True

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   NaN
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   NaN

# %%
df.fillna(value=9.5, inplace=True)

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   9.5
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   9.5

# %%
pd.to_datetime('20180214')
# Out:
# Timestamp('2018-02-14 00:00:00')

# %%
df.drop(pd.to_datetime('20180214'))
# Out:
#                    A         B         C         D    E
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979  9.5
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124  9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254  8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152  9.5

# %%
df.drop([pd.to_datetime('20180214'),pd.to_datetime('20180215')])
# Out:
#                    A         B         C         D    E
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124  9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254  8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152  9.5

# %%
#df.drop(pd.to_datetime('20180214'):pd.to_datetime('20180215'))

# %%
df
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   9.5
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124   9.0
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   9.5

# %%
df.drop('E', axis=1)
# Out:
#                    A         B         C         D
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979
# 2018-02-16  0.511370 -1.078917 -0.854772  0.517124
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152

# %%
df.drop(['A','B'], axis=1)
# Out:
#                    C         D     E
# 2018-02-14  0.379224  0.414422  10.0
# 2018-02-15 -1.856481  0.438979   9.5
# 2018-02-16 -0.854772  0.517124   9.0
# 2018-02-17  0.580658 -0.451254   8.0
# 2018-02-18  2.397624  0.943152   9.5

# %%
df.drop(df.index[2])
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   9.5
# 2018-02-17 -0.221041 -0.343906  0.580658 -0.451254   8.0
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   9.5

# %%
df.drop(df.index[[2,3]])
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   9.5
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   9.5

# %%
df.drop(df.index[2:4])
# Out:
#                    A         B         C         D     E
# 2018-02-14 -1.257992  0.260599  0.379224  0.414422  10.0
# 2018-02-15  0.520824 -0.950151 -1.856481  0.438979   9.5
# 2018-02-18 -0.164922 -0.258214  2.397624  0.943152   9.5
