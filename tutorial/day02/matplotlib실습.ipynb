# %%
# %matplotlib nbagg

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
sr = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
sr
# Out:
# 0     1.201145
# 10    2.955715
# 20    5.308309
# 30    4.929645
# 40    2.058410
# 50    0.494029
# 60    0.775245
# 70    1.010882
# 80    0.887577
# 90    0.590962
# dtype: float64

# %%
sr.plot() 
plt.savefig('figure1.svg')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10)) 
df
# Out:
#            A         B         C         D
# 0  -1.284180 -0.488402  1.292556 -0.734548
# 10 -0.972550 -1.011097  1.490706 -0.109297
# 20 -1.798002 -1.216432  1.608755 -0.099109
# 30 -1.381657 -1.342750  1.488184 -0.401605
# 40 -3.016204 -2.393279  1.713826 -0.579964
# 50 -4.473213 -2.777375  1.976941 -0.965765
# 60 -3.885708 -1.779083  2.329386 -0.560216
# 70 -5.300672 -1.692974  3.303070 -0.580280
# 80 -5.948885 -1.628482  2.927924 -1.727407
# 90 -4.809988 -2.670027  2.827675 -1.788680

# %%
df.plot()
plt.savefig('f2.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['A'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))
sr2
# Out:
# a    0.569183
# b    0.850219
# c    0.789020
# d    0.397107
# e    0.364788
# f    0.637891
# g    0.835955
# h    0.749787
# i    0.219879
# j    0.174398
# k    0.869009
# l    0.696945
# m    0.506937
# n    0.492757
# o    0.950742
# dtype: float64

# %%
sr2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr2.plot(kind='bar')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(pd.__version__)
# Out:
# 0.23.0

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Number")) 
df2
# Out:
# Number         A         B         C         D
# one     0.379343  0.471279  0.672446  0.326084
# two     0.670954  0.725673  0.605961  0.337845
# three   0.956882  0.574780  0.934763  0.125294
# four    0.894406  0.088665  0.023104  0.458629
# five    0.081407  0.350065  0.474556  0.887931
# six     0.031540  0.251523  0.780338  0.807443

# %%
df2.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
sr3.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr3.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))

# %%
x1
# Out:
# array([[ -4.01063969e-01],
#        [  7.07137151e-01],
#        [  4.72320643e-01],
#        [  4.70250995e-01],
#        [  4.50381067e-01],
#        [  2.57628927e+00],
#        [  1.38715808e+00],
#        [  1.02339728e+00],
#        [  3.89075201e-01],
#        [  2.37223079e-01],
#        [  1.00852895e+00],
#        [  5.28915302e-01],
#        [  1.11560044e+00],
#        [  2.40114114e+00],
#        [ -1.14767316e+00],
#        [  4.89367953e-01],
#        [  5.02328280e-02],
#        [  9.66225095e-01],
#        [  1.23257852e+00],
#        [  1.34146893e+00],
#        [  1.17601073e+00],
#        [  5.61068406e-02],
#        [ -2.59380869e-03],
#        [  9.68699018e-02],
#        [  5.01867430e-01],
#        [  1.57321234e+00],
#        [  2.05623088e+00],
#        [  9.89984315e-01],
#        [  2.18837928e+00],
#        [  1.94793972e+00],
#        [  1.06263104e+00],
#        [  1.41876446e+00],
#        [  2.53120292e+00],
#        [ -4.10381007e-01],
#        [  1.05273944e-02],
#        [  1.53903365e+00],
#        [  3.08417239e+00],
#        [  1.39184129e+00],
#        [  5.11489680e-01],
#        [  1.38278364e+00],
#        [  1.68948691e+00],
#        [  2.84826489e+00],
#        [  1.83714159e+00],
#        [  1.08412046e+00],
#        [  4.12834464e-01],
#        [  1.91775702e+00],
#        [  1.86170043e+00],
#        [  1.00456800e+00],
#        [  1.65695174e+00],
#        [  1.89144080e+00],
#        [  2.39560946e-01],
#        [  2.56421518e+00],
#        [  1.24218983e+00],
#        [  9.18773131e-01],
#        [  1.87870363e+00],
#        [  1.78907309e+00],
#        [  1.44274828e+00],
#        [ -1.29358188e+00],
#        [  1.99563361e+00],
#        [  2.04024374e+00],
#        [  1.65420100e+00],
#        [  2.22071690e+00],
#        [  2.27894697e-01],
#        [  1.71732776e+00],
#        [  1.29888633e+00],
#        [  2.02018805e+00],
#        [  1.73850284e+00],
#        [  4.03844064e-01],
#        [ -8.66304332e-01],
#        [ -2.13091397e-01],
#        [  1.64904928e+00],
#        [  3.46789136e-02],
#        [  1.53002759e+00],
#        [  1.73727797e+00],
#        [  3.97741607e-01],
#        [  1.39635041e+00],
#        [  1.18604884e+00],
#        [ -9.02938489e-01],
#        [  6.47419484e-01],
#        [ -6.10811415e-01],
#        [  4.37887937e-01],
#        [  5.72644713e-01],
#        [ -5.93457278e-01],
#        [  5.45223061e-01],
#        [  1.27416324e+00],
#        [ -1.59588616e+00],
#        [  3.60100369e-01],
#        [  4.15027225e-01],
#        [  1.94691982e-01],
#        [  9.45224047e-01],
#        [  1.06850448e+00],
#        [  1.02236894e+00],
#        [  3.56696152e-01],
#        [  7.41458737e-01],
#        [  1.66341545e+00],
#        [  1.58844448e+00],
#        [ -1.11605371e-01],
#        [  3.03152537e+00],
#        [  2.25288137e+00],
#        [  3.09551560e-01]])

# %%
x2
# Out:
# array([[ -1.66266884],
#        [  7.14551608],
#        [ -0.97616541],
#        [ -3.81788329],
#        [ -1.69435998],
#        [ -0.18749237],
#        [ -2.62732867],
#        [ -1.51306434],
#        [ -2.34190978],
#        [ -1.40865331],
#        [ -7.43181332],
#        [ -0.52473081],
#        [  8.02562943],
#        [ -0.99014647],
#        [  2.75516031],
#        [  0.60851627],
#        [ -3.80185013],
#        [ -6.62801562],
#        [ -1.31706126],
#        [  3.31431068],
#        [ -7.51857646],
#        [ -1.75439368],
#        [ -1.01264741],
#        [ -4.04908081],
#        [  1.21659419],
#        [ -5.55175659],
#        [  1.88712285],
#        [ -1.74311451],
#        [ -4.11416391],
#        [ -3.19065601],
#        [-11.79507594],
#        [ -2.61414281],
#        [ -8.80819236],
#        [ -3.2088107 ],
#        [ -2.12698396],
#        [ -4.41826086],
#        [  1.73647919],
#        [ -3.65582461],
#        [  4.47565481],
#        [ -0.48813776],
#        [  2.23215481],
#        [ -1.45400643],
#        [ -8.66150725],
#        [ -3.76398019],
#        [ -1.38890379],
#        [ -4.9572709 ],
#        [  1.29053718],
#        [ -2.23585479],
#        [ -6.80918219],
#        [ -1.82235974],
#        [  4.98122889],
#        [ -4.7723473 ],
#        [ -5.26463741],
#        [  2.21067853],
#        [ -7.68168027],
#        [ -4.37057676],
#        [  0.05279212],
#        [ -3.54812864],
#        [  4.22405474],
#        [  1.38102025],
#        [ -1.7203905 ],
#        [ -0.41957888],
#        [  1.14136662],
#        [  3.08926696],
#        [ -4.14832402],
#        [  0.64232922],
#        [ -8.04302379],
#        [  0.89410034],
#        [  1.16984734],
#        [ -7.34460579],
#        [ -2.41058512],
#        [ -2.023226  ],
#        [  3.21127995],
#        [ -3.04592309],
#        [ -3.50544034],
#        [ -3.60872002],
#        [  2.41942687],
#        [  2.31443093],
#        [ -2.52092153],
#        [  1.84145959],
#        [ -3.58591932],
#        [  0.67653754],
#        [ -7.73441379],
#        [ -5.93533394],
#        [  0.96545374],
#        [ -4.37795345],
#        [  3.99959153],
#        [  0.85725665],
#        [ -4.26635296],
#        [ -0.14727171],
#        [ -4.05244937],
#        [ -3.14775561],
#        [ -4.99712774],
#        [ -6.7194153 ],
#        [ -2.56764853],
#        [ -3.61956963],
#        [ -5.53115212],
#        [  0.55153275],
#        [ -4.73616717],
#        [ -0.19550935]])

# %%
X = np.concatenate((x1, x2), axis=1)

# %%
X
# Out:
# array([[ -4.01063969e-01,  -1.66266884e+00],
#        [  7.07137151e-01,   7.14551608e+00],
#        [  4.72320643e-01,  -9.76165407e-01],
#        [  4.70250995e-01,  -3.81788329e+00],
#        [  4.50381067e-01,  -1.69435998e+00],
#        [  2.57628927e+00,  -1.87492369e-01],
#        [  1.38715808e+00,  -2.62732867e+00],
#        [  1.02339728e+00,  -1.51306434e+00],
#        [  3.89075201e-01,  -2.34190978e+00],
#        [  2.37223079e-01,  -1.40865331e+00],
#        [  1.00852895e+00,  -7.43181332e+00],
#        [  5.28915302e-01,  -5.24730806e-01],
#        [  1.11560044e+00,   8.02562943e+00],
#        [  2.40114114e+00,  -9.90146474e-01],
#        [ -1.14767316e+00,   2.75516031e+00],
#        [  4.89367953e-01,   6.08516273e-01],
#        [  5.02328280e-02,  -3.80185013e+00],
#        [  9.66225095e-01,  -6.62801562e+00],
#        [  1.23257852e+00,  -1.31706126e+00],
#        [  1.34146893e+00,   3.31431068e+00],
#        [  1.17601073e+00,  -7.51857646e+00],
#        [  5.61068406e-02,  -1.75439368e+00],
#        [ -2.59380869e-03,  -1.01264741e+00],
#        [  9.68699018e-02,  -4.04908081e+00],
#        [  5.01867430e-01,   1.21659419e+00],
#        [  1.57321234e+00,  -5.55175659e+00],
#        [  2.05623088e+00,   1.88712285e+00],
#        [  9.89984315e-01,  -1.74311451e+00],
#        [  2.18837928e+00,  -4.11416391e+00],
#        [  1.94793972e+00,  -3.19065601e+00],
#        [  1.06263104e+00,  -1.17950759e+01],
#        [  1.41876446e+00,  -2.61414281e+00],
#        [  2.53120292e+00,  -8.80819236e+00],
#        [ -4.10381007e-01,  -3.20881070e+00],
#        [  1.05273944e-02,  -2.12698396e+00],
#        [  1.53903365e+00,  -4.41826086e+00],
#        [  3.08417239e+00,   1.73647919e+00],
#        [  1.39184129e+00,  -3.65582461e+00],
#        [  5.11489680e-01,   4.47565481e+00],
#        [  1.38278364e+00,  -4.88137764e-01],
#        [  1.68948691e+00,   2.23215481e+00],
#        [  2.84826489e+00,  -1.45400643e+00],
#        [  1.83714159e+00,  -8.66150725e+00],
#        [  1.08412046e+00,  -3.76398019e+00],
#        [  4.12834464e-01,  -1.38890379e+00],
#        [  1.91775702e+00,  -4.95727090e+00],
#        [  1.86170043e+00,   1.29053718e+00],
#        [  1.00456800e+00,  -2.23585479e+00],
#        [  1.65695174e+00,  -6.80918219e+00],
#        [  1.89144080e+00,  -1.82235974e+00],
#        [  2.39560946e-01,   4.98122889e+00],
#        [  2.56421518e+00,  -4.77234730e+00],
#        [  1.24218983e+00,  -5.26463741e+00],
#        [  9.18773131e-01,   2.21067853e+00],
#        [  1.87870363e+00,  -7.68168027e+00],
#        [  1.78907309e+00,  -4.37057676e+00],
#        [  1.44274828e+00,   5.27921217e-02],
#        [ -1.29358188e+00,  -3.54812864e+00],
#        [  1.99563361e+00,   4.22405474e+00],
#        [  2.04024374e+00,   1.38102025e+00],
#        [  1.65420100e+00,  -1.72039050e+00],
#        [  2.22071690e+00,  -4.19578880e-01],
#        [  2.27894697e-01,   1.14136662e+00],
#        [  1.71732776e+00,   3.08926696e+00],
#        [  1.29888633e+00,  -4.14832402e+00],
#        [  2.02018805e+00,   6.42329220e-01],
#        [  1.73850284e+00,  -8.04302379e+00],
#        [  4.03844064e-01,   8.94100341e-01],
#        [ -8.66304332e-01,   1.16984734e+00],
#        [ -2.13091397e-01,  -7.34460579e+00],
#        [  1.64904928e+00,  -2.41058512e+00],
#        [  3.46789136e-02,  -2.02322600e+00],
#        [  1.53002759e+00,   3.21127995e+00],
#        [  1.73727797e+00,  -3.04592309e+00],
#        [  3.97741607e-01,  -3.50544034e+00],
#        [  1.39635041e+00,  -3.60872002e+00],
#        [  1.18604884e+00,   2.41942687e+00],
#        [ -9.02938489e-01,   2.31443093e+00],
#        [  6.47419484e-01,  -2.52092153e+00],
#        [ -6.10811415e-01,   1.84145959e+00],
#        [  4.37887937e-01,  -3.58591932e+00],
#        [  5.72644713e-01,   6.76537541e-01],
#        [ -5.93457278e-01,  -7.73441379e+00],
#        [  5.45223061e-01,  -5.93533394e+00],
#        [  1.27416324e+00,   9.65453744e-01],
#        [ -1.59588616e+00,  -4.37795345e+00],
#        [  3.60100369e-01,   3.99959153e+00],
#        [  4.15027225e-01,   8.57256655e-01],
#        [  1.94691982e-01,  -4.26635296e+00],
#        [  9.45224047e-01,  -1.47271706e-01],
#        [  1.06850448e+00,  -4.05244937e+00],
#        [  1.02236894e+00,  -3.14775561e+00],
#        [  3.56696152e-01,  -4.99712774e+00],
#        [  7.41458737e-01,  -6.71941530e+00],
#        [  1.66341545e+00,  -2.56764853e+00],
#        [  1.58844448e+00,  -3.61956963e+00],
#        [ -1.11605371e-01,  -5.53115212e+00],
#        [  3.03152537e+00,   5.51532746e-01],
#        [  2.25288137e+00,  -4.73616717e+00],
#        [  3.09551560e-01,  -1.95509353e-01]])

# %%
type(X)
# Out:
# numpy.ndarray

# %%
df3 = pd.DataFrame(X, columns=['x1','x2']) 
df3
# Out:
#           x1        x2
# 0  -0.401064 -1.662669
# 1   0.707137  7.145516
# 2   0.472321 -0.976165
# 3   0.470251 -3.817883
# 4   0.450381 -1.694360
# 5   2.576289 -0.187492
# 6   1.387158 -2.627329
# 7   1.023397 -1.513064
# 8   0.389075 -2.341910
# 9   0.237223 -1.408653
# 10  1.008529 -7.431813
# 11  0.528915 -0.524731
# 12  1.115600  8.025629
# 13  2.401141 -0.990146
# 14 -1.147673  2.755160
# 15  0.489368  0.608516
# 16  0.050233 -3.801850
# 17  0.966225 -6.628016
# 18  1.232579 -1.317061
# 19  1.341469  3.314311
# 20  1.176011 -7.518576
# 21  0.056107 -1.754394
# 22 -0.002594 -1.012647
# 23  0.096870 -4.049081
# 24  0.501867  1.216594
# 25  1.573212 -5.551757
# 26  2.056231  1.887123
# 27  0.989984 -1.743115
# 28  2.188379 -4.114164
# 29  1.947940 -3.190656
# ..       ...       ...
# 70  1.649049 -2.410585
# 71  0.034679 -2.023226
# 72  1.530028  3.211280
# 73  1.737278 -3.045923
# 74  0.397742 -3.505440
# 75  1.396350 -3.608720
# 76  1.186049  2.419427
# 77 -0.902938  2.314431
# 78  0.647419 -2.520922
# 79 -0.610811  1.841460
# 80  0.437888 -3.585919
# 81  0.572645  0.676538
# 82 -0.593457 -7.734414
# 83  0.545223 -5.935334
# 84  1.274163  0.965454
# 85 -1.595886 -4.377953
# 86  0.360100  3.999592
# 87  0.415027  0.857257
# 88  0.194692 -4.266353
# 89  0.945224 -0.147272
# 90  1.068504 -4.052449
# 91  1.022369 -3.147756
# 92  0.356696 -4.997128
# 93  0.741459 -6.719415
# 94  1.663415 -2.567649
# 95  1.588444 -3.619570
# 96 -0.111605 -5.531152
# 97  3.031525  0.551533
# 98  2.252881 -4.736167
# 99  0.309552 -0.195509
#
# [100 rows x 2 columns]

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.scatter(df3['x1'], df3['x2'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
series = pd.Series(3 * np.random.rand(4), index=['a','b','c','d'], name='series')

# %%
series.plot.pie(figsize=(6,6))
# Out:
# <img src="data:image/png;base64,..." width="599.68">

# %%
df = pd.DataFrame(3 * np.random.rand(4,2),
                  index=['a','b','c','d'], columns=['x','y'])

# %%
df
# Out:
#           x         y
# a  0.767932  2.780754
# b  2.513676  2.296870
# c  2.718459  2.284255
# d  1.797609  0.415752

# %%
df.plot.pie(subplots=True, figsize=(8,4))
# Out:
# <img src="data:image/png;base64,..." width="800">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F10DBE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E8548D0>], dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(8,4)) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
